# %% [markdown]
# <a href="https://colab.research.google.com/github/ajankowi/magisterka/blob/master/Testing_styleGAN2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import torch

from PIL import Image

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

available_gpus = [torch.cuda.device(i) for i in range(torch.cuda.device_count())]
print(available_gpus)

num_of_gpus = torch.cuda.device_count()
print(num_of_gpus)
# Out:
# Using device: cuda
# ...
# 1

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !python drive/MyDrive/MNIST/StyleGAN2/dataset_tool_gray.py --source=/content/drive/MyDrive/MNIST/four_img.zip --dest=/content/dataset_floder.zip --transform=center-crop --width=16 --height=16
# Out:
#   0% 0/5842 [00:00<?, ?it/s]{'width': 16, 'height': 16, 'channels': 1}
# 100% 5842/5842 [00:04<00:00, 1309.72it/s]

# %%
# !python drive/MyDrive/MNIST/StyleGAN2/train.py --outdir=/content/drive/MyDrive/MNIST/outdir --data=/content/dataset_floder.zip --gpus=1 --cfg=auto
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/dataset_floder.zip",
#     "use_labels": false,
#     "max_size": 5842,
#     "xflip": false,
#     "resolution": 16
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...
