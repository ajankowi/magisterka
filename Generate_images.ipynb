# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

from PIL import Image

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# !pip install ninja
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 212 (delta 0), reused 1 (delta 0), pack-reused 207
# Receiving objects: 100% (212/212), 4.17 MiB | 15.43 MiB/s, done.
# Resolving deltas: 100% (98/98), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade torch==2.1.0+cu121 torchvision==0.16.0+cu121 -f https://download.pytorch.org/whl/torch_stable.html


#!pip install jaxlib==0.4.0
#!pip install torch==1.11.0 torchvision==0.12.0
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 GB 441.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 102.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 9.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.17.1+cu121
#     Uninstalling torchvision-0.17.1+cu121:
#       Successfully uninstalled torchvision-0.17.1+cu121
# ...

# %%
import sys
sys.path.insert(0, "/content/stylegan3")
import pickle
import os
import numpy as np
import PIL.Image
from IPython.display import Image
import matplotlib.pyplot as plt
import IPython.display
import torch
import dnnlib
import legacy

# %%
device = torch.device('cuda')

# %%
print(f"Using device: {device}")

num_of_gpus = torch.cuda.device_count()
print(num_of_gpus)
# Out:
# Using device: cuda
# 1

# %%
for i in range(31,39):
  print(i)
  # !python /content/drive/MyDrive/Magisterka/stylegan3-main/gen_images.py --outdir=/content/drive/MyDrive/Magisterka/Models/{i}/img --seeds=0-200 --network=/content/drive/MyDrive/Magisterka/Models/{i}/network-snapshot-000200.pkl
# Out:
# 31
# Loading networks from "/content/drive/MyDrive/Magisterka/Models/31/network-snapshot-000200.pkl"...
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Magisterka/stylegan3-main/gen_images.py", line 147, in <module>
#     generate_images() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/content/drive/MyDrive/Magisterka/stylegan3-main/gen_images.py", line 107, in generate_images
#     with dnnlib.util.open_url(network_pkl) as f:
# ...

# %%
# !python /content/drive/MyDrive/Magisterka/stylegan3-main/gen_images.py --outdir=/content/drive/MyDrive/Magisterka/Models/3/img --seeds=0-10 --network=/content/drive/MyDrive/Magisterka/Models/1/network-snapshot-000200.pkl
# Out:
# Loading networks from "/content/drive/MyDrive/Magisterka/Models/1/network-snapshot-000200.pkl"...
# Generating image for seed 0 (0/11) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# torch.Size([64, 64])
# Generating image for seed 1 (1/11) ...
# torch.Size([64, 64])
# Generating image for seed 2 (2/11) ...
# torch.Size([64, 64])
# Generating image for seed 3 (3/11) ...
# torch.Size([64, 64])
# Generating image for seed 4 (4/11) ...
# torch.Size([64, 64])
# Generating image for seed 5 (5/11) ...
# torch.Size([64, 64])
# Generating image for seed 6 (6/11) ...
# torch.Size([64, 64])
# Generating image for seed 7 (7/11) ...
# torch.Size([64, 64])
# Generating image for seed 8 (8/11) ...
# torch.Size([64, 64])
# Generating image for seed 9 (9/11) ...
# torch.Size([64, 64])
# Generating image for seed 10 (10/11) ...
# torch.Size([64, 64])
