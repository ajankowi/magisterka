# %%
import sys
print(sys.version)
# Out:
# 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers, models, regularizers
from keras.layers import Flatten, add, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping


print("TensorFlow version:", tf.__version__)
tf.keras.backend.set_floatx('float64')
# Out:
# TensorFlow version: 2.10.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os
import csv
import random

import cv2
import glob
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
#Wczytanie etykiet do treninegu

with open('../../Dataset_both/Real/Szum/Train/train.csv',"r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_train = []
for i in new[0]:
    value_train.append(int(i))

print(len(value_train))
# Out:
# 30240

# %%
#Wczytanie etykiet do walidacji

with open('../../Dataset_both/Real/Szum/Valid/valid.csv',"r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_valid = []
for i in new[0]:
    value_valid.append(int(i))

print(len(value_valid))
# Out:
# 2520

# %%
#Wczytanie etykiet do testowania

with open('../../Dataset_both/Real/Test/test.csv',"r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_test = []
for i in new[0]:
    value_test.append(int(i))

print(len(value_test))
# Out:
# 2520

# %%
#Wczytanie zdjęć treningowych (75% całego zbioru)
images_train = []
size = len(value_train)

for i in range(size):
    im = Image.open('../../Dataset_both/Real/Train/'+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_train.append(arr_im)
print(len(images_train))
# Out:
# 15120

# %%
#Wczytanie zdjęć walidacji (12,5% całego zbioru)
images_valid = []
size = len(value_valid)

for i in range(size):
    im = Image.open('../../Dataset_both/Real/Valid/'+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_valid.append(arr_im)
print(len(images_valid))
# Out:
# 2520

# %%
#Wczytanie zdjęć testowych (12,5% całego zbioru)
images_test = []
size = len(value_test)

for i in range(size):
    im = Image.open('../../Dataset_both/Real/Test/'+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_test.append(arr_im)
print(len(images_test))
# Out:
# 2520

# %%
x_train = np.array(images_train)
y_train = np.array(value_train)

x_valid = np.array(images_valid)
y_valid = np.array(value_valid)

x_test = np.array(images_test)
y_test = np.array(value_test)

# %%
a = 1000
plt.imshow(x_train[a],cmap = 'gray')
print(y_train[a])
# Out:
# 1

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.BatchNormalization())

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 62, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 63, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 14, 32)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 30, 14, 32)       128
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 28, 12, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 6, 64)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 4, 64)         36928
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 2, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 6, 2, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense (Dense)               (None, 64)                49216
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 114,657
# Trainable params: 114,465
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy','mse'])

#Funcka umożliwia zatrzymanie się uczenia
#gdy wartość strat przstanie maleć
EarlyStop = EarlyStopping(monitor='val_loss',
                          verbose=1,
                          patience=10)


ModelCheck = ModelCheckpoint(filepath='./Model_przeplatane_wiersze_2.h5',
                             monitor='val_loss',
                             save_best_only=True)

history = model.fit(x=x_train,
                    y=y_train,
                    epochs=100,
                    batch_size=128,
                    #validation_split=0.1,
                    validation_data = (x_valid, y_valid),
                    callbacks = [EarlyStop, ModelCheck]
                   )
# Out:
# Epoch 1/100
# 119/119 [==============================] - 26s 209ms/step - loss: 0.1456 - accuracy: 0.8579 - mse: 0.1456 - val_loss: 0.5000 - val_accuracy: 0.5000 - val_mse: 0.5000
# Epoch 2/100
# 119/119 [==============================] - 24s 204ms/step - loss: 0.0211 - accuracy: 0.9830 - mse: 0.0211 - val_loss: 0.5000 - val_accuracy: 0.5000 - val_mse: 0.5000
# 119/119 [==============================] - 29s 241ms/step - loss: 9.7291e-04 - accuracy: 1.0000 - mse: 9.7291e-04 - val_loss: 0.1070 - val_accuracy: 0.8607 - val_mse: 0.1070
# Epoch 17/100
# 119/119 [==============================] - 29s 244ms/step - loss: 8.4305e-04 - accuracy: 1.0000 - mse: 8.4305e-04 - val_loss: 0.1016 - val_accuracy: 0.8603 - val_mse: 0.1016
# Epoch 18/100
# 119/119 [==============================] - 29s 243ms/step - loss: 0.0012 - accuracy: 0.9999 - mse: 0.0012 - val_loss: 0.1155 - val_accuracy: 0.8544 - val_mse: 0.1155
# Epoch 19/100
# 119/119 [==============================] - 29s 244ms/step - loss: 8.3479e-04 - accuracy: 1.0000 - mse: 8.3479e-04 - val_loss: 0.1125 - val_accuracy: 0.8599 - val_mse: 0.1125
# Epoch 20/100
# 119/119 [==============================] - 29s 243ms/step - loss: 6.5993e-04 - accuracy: 1.0000 - mse: 6.5993e-04 - val_loss: 0.1109 - val_accuracy: 0.8560 - val_mse: 0.1109
# Epoch 21/100
# 119/119 [==============================] - 29s 244ms/step - loss: 5.2511e-04 - accuracy: 1.0000 - mse: 5.2511e-04 - val_loss: 0.1066 - val_accuracy: 0.8627 - val_mse: 0.1066
# Epoch 22/100
# 119/119 [==============================] - 29s 244ms/step - loss: 0.0011 - accuracy: 0.9998 - mse: 0.0011 - val_loss: 0.1097 - val_accuracy: 0.8480 - val_mse: 0.1097
# Epoch 23/100
# 119/119 [==============================] - 29s 244ms/step - loss: 0.0043 - accuracy: 0.9987 - mse: 0.0043 - val_loss: 0.2346 - val_accuracy: 0.7103 - val_mse: 0.2346
# Epoch 24/100
# 119/119 [==============================] - 29s 244ms/step - loss: 0.0010 - accuracy: 0.9999 - mse: 0.0010 - val_loss: 0.1119 - val_accuracy: 0.8524 - val_mse: 0.1119
# Epoch 25/100
# 119/119 [==============================] - 29s 244ms/step - loss: 7.9587e-04 - accuracy: 0.9999 - mse: 7.9587e-04 - val_loss: 0.1201 - val_accuracy: 0.8508 - val_mse: 0.1201
# Epoch 26/100
# 119/119 [==============================] - 29s 244ms/step - loss: 4.7603e-04 - accuracy: 1.0000 - mse: 4.7603e-04 - val_loss: 0.0892 - val_accuracy: 0.8853 - val_mse: 0.0892
# Epoch 27/100
# 119/119 [==============================] - 29s 243ms/step - loss: 4.1346e-04 - accuracy: 1.0000 - mse: 4.1346e-04 - val_loss: 0.1107 - val_accuracy: 0.8544 - val_mse: 0.1107
# Epoch 28/100
# 119/119 [==============================] - 29s 244ms/step - loss: 4.9355e-04 - accuracy: 0.9999 - mse: 4.9355e-04 - val_loss: 0.2013 - val_accuracy: 0.7183 - val_mse: 0.2013
# Epoch 29/100
# 119/119 [==============================] - 29s 243ms/step - loss: 0.0079 - accuracy: 0.9937 - mse: 0.0079 - val_loss: 0.1399 - val_accuracy: 0.8262 - val_mse: 0.1399
# Epoch 30/100
# 119/119 [==============================] - 29s 244ms/step - loss: 0.0018 - accuracy: 0.9990 - mse: 0.0018 - val_loss: 0.1500 - val_accuracy: 0.8127 - val_mse: 0.1500
# Epoch 31/100
# 119/119 [==============================] - 29s 244ms/step - loss: 8.2732e-04 - accuracy: 0.9998 - mse: 8.2732e-04 - val_loss: 0.1010 - val_accuracy: 0.8813 - val_mse: 0.1010
# Epoch 32/100
# 119/119 [==============================] - 29s 243ms/step - loss: 6.6822e-04 - accuracy: 0.9999 - mse: 6.6822e-04 - val_loss: 0.1137 - val_accuracy: 0.8643 - val_mse: 0.1137
# Epoch 33/100
# 119/119 [==============================] - 29s 243ms/step - loss: 4.6153e-04 - accuracy: 0.9999 - mse: 4.6153e-04 - val_loss: 0.1050 - val_accuracy: 0.8810 - val_mse: 0.1050
# Epoch 34/100
# 119/119 [==============================] - 29s 244ms/step - loss: 4.7119e-04 - accuracy: 1.0000 - mse: 4.7119e-04 - val_loss: 0.1223 - val_accuracy: 0.8532 - val_mse: 0.1223
# Epoch 35/100
# 119/119 [==============================] - 29s 244ms/step - loss: 3.2205e-04 - accuracy: 1.0000 - mse: 3.2205e-04 - val_loss: 0.1723 - val_accuracy: 0.7829 - val_mse: 0.1723
# Epoch 36/100
# 119/119 [==============================] - 29s 244ms/step - loss: 3.4276e-04 - accuracy: 1.0000 - mse: 3.4276e-04 - val_loss: 0.1757 - val_accuracy: 0.7952 - val_mse: 0.1757
# Epoch 36: early stopping

# %%
plt.plot(history.history['loss'], label='strata')
plt.plot(history.history['val_loss'], label = 'strata walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Strata')
plt.ylim([0.0, 0.5])
plt.legend(loc='upper right')

# %%
plt.plot(history.history['accuracy'], label='precyzja')
plt.plot(history.history['val_accuracy'], label = 'precyzja walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Precyzja')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
best_model = tf.keras.models.load_model('./Model_przeplatane_wiersze_2.h5')

# %%
best_model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 79/79 - 2s - loss: 0.0756 - accuracy: 0.8980 - mse: 0.0756 - 2s/epoch - 27ms/step
# [0.07564270834638993, 0.898015873015873, 0.07564270834638993]

# %%
predict_x = best_model.predict(x_test)

predictions = (predict_x > 0.5).astype("int32")
# Out:
# 79/79 [==============================] - 2s 21ms/step

# %%
names = [['Tn','Nn'],['Np', 'Tp']]
names = np.reshape(names,(2,2))
print(names)

conf = tf.math.confusion_matrix(y_test,predictions)

print(conf)
# Out:
# [['Tn' 'Nn']
#  ['Np' 'Tp']]
# tf.Tensor(
# [[1224   36]
#  [ 221 1039]], shape=(2, 2), dtype=int32)
