# %%
import sys
print(sys.version)
# Out:
# 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers, models, regularizers
from keras.layers import Flatten, add, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping
import gc

print("TensorFlow version:", tf.__version__)
tf.keras.backend.set_floatx('float64')
# Out:
# TensorFlow version: 2.10.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os
import csv
import random

import cv2
import glob
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
print(tf.config.list_physical_devices('GPU'))

# %%
#Określenie ścieżek do plików
test_csv = 'Test/test.csv'
valid_csv = 'Valid/valid.csv'
train_csv = 'Train/train.csv'

folder = '/content/drive/MyDrive/Sieci_rozszerzenie/Przeplatane_wiersze/'
slesh = '/'
png = '.png'

# %%
#Wczytanie etykiet do treninegu

with open('../../Dataset_both/Fake/Train/train.csv',"r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_train = []
for i in new[0]:
    value_train.append(int(i))

print(len(value_train))
# Out:
# 237600

# %%
#Wczytanie etykiet do walidacji

with open('../../Dataset_both/Real/Valid/valid.csv',"r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_valid = []
for i in new[0]:
    value_valid.append(int(i))

print(len(value_valid))
# Out:
# 2520

# %%
#Wczytanie etykiet do testowania

with open('../../Dataset_both/Real/Valid/valid.csv',"r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_test = []
for i in new[0]:
    value_test.append(int(i))

print(len(value_test))
# Out:
# 2520

# %%
#Wczytanie zdjęć treningowych (75% całego zbioru)
images_train = []
size = len(value_train)

for i in range(size):
    im = Image.open('../../Dataset_both/Fake/Train/'+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_train.append(arr_im)
print(len(images_train))
# Out:
# 237600

# %%
#Wczytanie zdjęć walidacji (12,5% całego zbioru)
images_valid = []
size = len(value_valid)

for i in range(size):
    im = Image.open('../../Dataset_both/Real/Valid/'+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_valid.append(arr_im)
print(len(images_valid))
# Out:
# 2520

# %%
#Wczytanie zdjęć testowych (12,5% całego zbioru)
images_test = []
size = len(value_test)

for i in range(size):
    im = Image.open('../../Dataset_both/Real/Test/'+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_test.append(arr_im)
print(len(images_test))
# Out:
# 2520

# %%
x_train = np.array(images_train)
y_train = np.array(value_train)

x_valid = np.array(images_valid)
y_valid = np.array(value_valid)

x_test = np.array(images_test)
y_test = np.array(value_test)

# %%
del images_train

gc.collect()
# Out:
# 331

# %%
a = 1000
plt.imshow(x_train[a],cmap = 'gray')
print(y_train[a])
# Out:
# 1

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.BatchNormalization())

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 126, 62, 32)       320
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 31, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 29, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 14, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 30, 14, 32)       128
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 28, 12, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 6, 64)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 4, 64)         36928
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 2, 64)         0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 6, 2, 64)         256
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 768)               0
#
#  dense_2 (Dense)             (None, 64)                49216
#
# ...

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# []
# python: can't open file 'c:\\Users\\jankowiaka\\Documents\\python\\mag\\face_recogniction\\Fake_no_labels\\pip': [Errno 2] No such file or directory

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy','mse'])

#Funcka umożliwia zatrzymanie się uczenia
#gdy wartość strat przstanie maleć
EarlyStop = EarlyStopping(monitor='val_loss',
                          verbose=1,
                          patience=25)


ModelCheck = ModelCheckpoint(filepath='./Model_przeplatane_wiersze_4.h5',
                             monitor='val_loss',
                             save_best_only=True)

history = model.fit(x=x_train,
                    y=y_train,
                    epochs=100,
                    batch_size=128,
                    #validation_split=0.1,
                    validation_data = (x_valid, y_valid),
                    callbacks = [EarlyStop, ModelCheck]
                   )
# Out:
# Epoch 1/100
#  513/1857 [=======>......................] - ETA: 23:49 - loss: 0.0232 - accuracy: 0.9707 - mse: 0.0232
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 16
#       7 EarlyStop = EarlyStopping(monitor='val_loss',
#       8                           verbose=1,
#       9                           patience=25)
#      12 ModelCheck = ModelCheckpoint(filepath='./Model_przeplatane_wiersze_4.h5',
#      13                              monitor='val_loss',
#      14                              save_best_only=True)
# ---> 16 history = model.fit(x=x_train,
#      17                     y=y_train,
#      18                     epochs=100,
#      19                     batch_size=128,
#      20                     #validation_split=0.1,
#      21                     validation_data = (x_valid, y_valid),
# ...

# %%
plt.plot(history.history['loss'], label='strata')
plt.plot(history.history['val_loss'], label = 'strata walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Strata')
plt.ylim([0.0, 0.5])
plt.legend(loc='upper right')

# %%
plt.plot(history.history['accuracy'], label='precyzja')
plt.plot(history.history['val_accuracy'], label = 'precyzja walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Precyzja')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
best_model = tf.keras.models.load_model('./Model_przeplatane_wiersze_4.h5')

# %%
best_model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 79/79 - 7s - loss: 0.2428 - accuracy: 0.7504 - mse: 0.2428 - 7s/epoch - 91ms/step
# [0.24279091405085282, 0.7503968253968254, 0.24279091405085282]

# %%
predict_x = best_model.predict(x_test)

predictions = (predict_x > 0.5).astype("int32")
# Out:
# 79/79 [==============================] - 7s 90ms/step

# %%
names = [['Tn','Nn'],['Np', 'Tp']]
names = np.reshape(names,(2,2))
print(names)

conf = tf.math.confusion_matrix(y_test,predictions)

print(conf)
# Out:
# [['Tn' 'Nn']
#  ['Np' 'Tp']]
# tf.Tensor(
# [[1234   26]
#  [ 603  657]], shape=(2, 2), dtype=int32)
