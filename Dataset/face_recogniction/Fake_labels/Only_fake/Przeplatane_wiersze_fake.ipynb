# %%
import sys
print(sys.version)
# Out:
# 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers, models, regularizers
from keras.layers import Flatten, add, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping


print("TensorFlow version:", tf.__version__)
tf.keras.backend.set_floatx('float64')
# Out:
# TensorFlow version: 2.10.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os
import csv
import random

import cv2
import glob
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
# Dane fikcyjne
#Wczytanie etykiet do treninegu 

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Fake_Label\Train\train.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))

value_train = []
for i in new[0]:
    value_train.append(int(i))

print(len(value_train))
# Out:
# 15120

# %%
#Wczytanie etykiet do walidacji

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Valid\valid.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_valid = []
for i in new[0]:
    value_valid.append(int(i))

print(len(value_valid))
# Out:
# 2520

# %%
#Wczytanie etykiet do testowania

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Test\test.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_test = []
for i in new[0]:
    value_test.append(int(i))

print(len(value_test))
# Out:
# 2520

# %%
#Dane fikcyjne
#Wczytanie zdjęć treningowych (75% całego zbioru)
images_train = []
size = int(len(value_train))

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Fake_Label\Train\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_train.append(arr_im)
print(len(images_train))
# Out:
# 15120

# %%
#Wczytanie zdjęć walidacji (12,5% całego zbioru)
images_valid = []
size = len(value_valid)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Valid\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_valid.append(arr_im)
print(len(images_valid))
# Out:
# 2520

# %%
#Wczytanie zdjęć testowych (12,5% całego zbioru)
images_test = []
size = len(value_test)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Test\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_test.append(arr_im)
print(len(images_test))
# Out:
# 2520

# %%
x_train = np.array(images_train)
y_train = np.array(value_train)

x_valid = np.array(images_valid)
y_valid = np.array(value_valid)

x_test = np.array(images_test)
y_test = np.array(value_test)

# %%
a = 10000
plt.imshow(x_train[a],cmap = 'gray')
print(y_train[a])
# Out:
# 0

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.BatchNormalization())

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 62, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 63, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 14, 32)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 30, 14, 32)       128
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 28, 12, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 6, 64)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 4, 64)         36928
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 2, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 6, 2, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense (Dense)               (None, 64)                49216
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 114,657
# Trainable params: 114,465
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy','mse'])

#Funcka umożliwia zatrzymanie się uczenia
#gdy wartość strat przstanie maleć
EarlyStop = EarlyStopping(monitor='val_loss',
                          verbose=1,
                          patience=10)


ModelCheck = ModelCheckpoint(filepath='./Model_przeplatane_wiersze_2.h5',
                             monitor='val_loss',
                             save_best_only=True)

history = model.fit(x=x_train,
                    y=y_train,
                    epochs=100,
                    batch_size=128,
                    #validation_split=0.1,
                    validation_data = (x_valid, y_valid),
                    callbacks = [EarlyStop, ModelCheck]
                   )
# Out:
# Epoch 1/100
# 119/119 [==============================] - 46s 375ms/step - loss: 0.0026 - accuracy: 0.9995 - mse: 0.0026 - val_loss: 0.4099 - val_accuracy: 0.5643 - val_mse: 0.4099
# Epoch 2/100
# 119/119 [==============================] - 44s 372ms/step - loss: 0.0026 - accuracy: 0.9994 - mse: 0.0026 - val_loss: 0.0969 - val_accuracy: 0.8746 - val_mse: 0.0969
# Epoch 3/100
# 119/119 [==============================] - 44s 369ms/step - loss: 0.0012 - accuracy: 0.9997 - mse: 0.0012 - val_loss: 0.1059 - val_accuracy: 0.8639 - val_mse: 0.1059
# Epoch 4/100
# 119/119 [==============================] - 43s 363ms/step - loss: 6.1053e-04 - accuracy: 1.0000 - mse: 6.1053e-04 - val_loss: 0.2154 - val_accuracy: 0.7607 - val_mse: 0.2154
# Epoch 5/100
# 119/119 [==============================] - 43s 364ms/step - loss: 8.0758e-04 - accuracy: 0.9999 - mse: 8.0758e-04 - val_loss: 0.0958 - val_accuracy: 0.8532 - val_mse: 0.0958
# Epoch 6/100
# 119/119 [==============================] - 43s 358ms/step - loss: 4.1278e-04 - accuracy: 1.0000 - mse: 4.1278e-04 - val_loss: 0.0797 - val_accuracy: 0.8929 - val_mse: 0.0797
# Epoch 7/100
# 119/119 [==============================] - 46s 385ms/step - loss: 5.1253e-04 - accuracy: 1.0000 - mse: 5.1253e-04 - val_loss: 0.0680 - val_accuracy: 0.9052 - val_mse: 0.0680
# Epoch 8/100
# 119/119 [==============================] - 46s 385ms/step - loss: 0.0012 - accuracy: 0.9995 - mse: 0.0012 - val_loss: 0.3029 - val_accuracy: 0.5298 - val_mse: 0.3029
# Epoch 9/100
# 119/119 [==============================] - 38s 319ms/step - loss: 0.0074 - accuracy: 0.9938 - mse: 0.0074 - val_loss: 0.1218 - val_accuracy: 0.8512 - val_mse: 0.1218
# Epoch 10/100
# 119/119 [==============================] - 38s 319ms/step - loss: 7.3788e-04 - accuracy: 0.9999 - mse: 7.3788e-04 - val_loss: 0.0692 - val_accuracy: 0.9083 - val_mse: 0.0692
# Epoch 11/100
# 119/119 [==============================] - 37s 312ms/step - loss: 5.5323e-04 - accuracy: 0.9998 - mse: 5.5323e-04 - val_loss: 0.1540 - val_accuracy: 0.8190 - val_mse: 0.1540
# Epoch 12/100
# 119/119 [==============================] - 38s 316ms/step - loss: 6.0227e-04 - accuracy: 0.9999 - mse: 6.0227e-04 - val_loss: 0.0645 - val_accuracy: 0.9115 - val_mse: 0.0645
# Epoch 13/100
# 119/119 [==============================] - 39s 326ms/step - loss: 3.5404e-04 - accuracy: 1.0000 - mse: 3.5404e-04 - val_loss: 0.0914 - val_accuracy: 0.8853 - val_mse: 0.0914
# Epoch 14/100
# 119/119 [==============================] - 41s 346ms/step - loss: 2.5256e-04 - accuracy: 1.0000 - mse: 2.5256e-04 - val_loss: 0.1380 - val_accuracy: 0.8337 - val_mse: 0.1380
# Epoch 15/100
# 119/119 [==============================] - 38s 317ms/step - loss: 2.6501e-04 - accuracy: 1.0000 - mse: 2.6501e-04 - val_loss: 0.2673 - val_accuracy: 0.7179 - val_mse: 0.2673
# Epoch 16/100
# 119/119 [==============================] - 38s 318ms/step - loss: 2.8643e-04 - accuracy: 1.0000 - mse: 2.8643e-04 - val_loss: 0.2565 - val_accuracy: 0.7230 - val_mse: 0.2565
# Epoch 17/100
# 119/119 [==============================] - 41s 344ms/step - loss: 2.3308e-04 - accuracy: 1.0000 - mse: 2.3308e-04 - val_loss: 0.1303 - val_accuracy: 0.8444 - val_mse: 0.1303
# Epoch 18/100
# 119/119 [==============================] - 46s 384ms/step - loss: 1.9149e-04 - accuracy: 1.0000 - mse: 1.9149e-04 - val_loss: 0.0655 - val_accuracy: 0.9075 - val_mse: 0.0655
# Epoch 19/100
# 119/119 [==============================] - 45s 382ms/step - loss: 5.4743e-04 - accuracy: 1.0000 - mse: 5.4743e-04 - val_loss: 0.2124 - val_accuracy: 0.7690 - val_mse: 0.2124
# Epoch 20/100
# 119/119 [==============================] - 46s 389ms/step - loss: 0.0012 - accuracy: 0.9995 - mse: 0.0012 - val_loss: 0.0854 - val_accuracy: 0.8948 - val_mse: 0.0854
# Epoch 21/100
# 119/119 [==============================] - 46s 387ms/step - loss: 8.3441e-04 - accuracy: 0.9997 - mse: 8.3441e-04 - val_loss: 0.1268 - val_accuracy: 0.8143 - val_mse: 0.1268
# Epoch 22/100
# 119/119 [==============================] - 46s 387ms/step - loss: 6.6152e-04 - accuracy: 0.9996 - mse: 6.6152e-04 - val_loss: 0.3173 - val_accuracy: 0.6698 - val_mse: 0.3173
# Epoch 22: early stopping

# %%
plt.plot(history.history['loss'], label='strata')
plt.plot(history.history['val_loss'], label = 'strata walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Strata')
plt.ylim([0.0, 0.5])
plt.legend(loc='upper right')

# %%
plt.plot(history.history['accuracy'], label='precyzja')
plt.plot(history.history['val_accuracy'], label = 'precyzja walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Precyzja')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
best_model = tf.keras.models.load_model('./Model_przeplatane_wiersze_1.h5')

# %%
best_model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 79/79 - 6s - loss: 0.1460 - accuracy: 0.8238 - mse: 0.1460 - 6s/epoch - 70ms/step
# [0.14603878456633163, 0.8238095238095238, 0.14603878456633163]

# %%
predict_x = best_model.predict(x_test)

predictions = (predict_x > 0.5).astype("int32")
# Out:
# 79/79 [==============================] - 5s 67ms/step

# %%
names = [['Tn','Nn'],['Np', 'Tp']]
names = np.reshape(names,(2,2))
print(names)

conf = tf.math.confusion_matrix(y_test,predictions)

print(conf)
# Out:
# [['Tn' 'Nn']
#  ['Np' 'Tp']]
# tf.Tensor(
# [[1185   75]
#  [ 369  891]], shape=(2, 2), dtype=int32)
