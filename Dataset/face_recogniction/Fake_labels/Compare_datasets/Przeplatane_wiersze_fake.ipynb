# %%
import sys
print(sys.version)
# Out:
# 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers, models, regularizers
from keras.layers import Flatten, add, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping


print("TensorFlow version:", tf.__version__)
tf.keras.backend.set_floatx('float64')
# Out:
# TensorFlow version: 2.10.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os
import csv
import random

import cv2
import glob
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
# Dane rzeczywiste
#Wczytanie etykiet do treninegu 

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Train\train.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_train = []
for i in new[0]:
    value_train.append(int(i))

print(len(value_train))
# Out:
# 15120

# %%
# Dane fikcyjne
#Wczytanie etykiet do treninegu 

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Fake_Label\Train\train.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))

for i in new[0]:
    value_train.append(int(i))

print(len(value_train))
# Out:
# 30240

# %%
#Wczytanie etykiet do walidacji

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Valid\valid.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_valid = []
for i in new[0]:
    value_valid.append(int(i))

print(len(value_valid))
# Out:
# 2520

# %%
#Wczytanie etykiet do testowania

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Test\test.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_test = []
for i in new[0]:
    value_test.append(int(i))

print(len(value_test))
# Out:
# 2520

# %%
#Dane rzeczywiste
#Wczytanie zdjęć treningowych (75% całego zbioru)
images_train = []
size = int(len(value_train)/2)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Train\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_train.append(arr_im)
print(len(images_train))
# Out:
# 15120

# %%
#Dane fikcyjne
#Wczytanie zdjęć treningowych (75% całego zbioru)
size = int(len(value_train)/2)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Fake_Label\Train\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_train.append(arr_im)
print(len(images_train))
# Out:
# 30240

# %%
#Wczytanie zdjęć walidacji (12,5% całego zbioru)
images_valid = []
size = len(value_valid)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Valid\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_valid.append(arr_im)
print(len(images_valid))
# Out:
# 2520

# %%
#Wczytanie zdjęć testowych (12,5% całego zbioru)
images_test = []
size = len(value_test)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Test\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_test.append(arr_im)
print(len(images_test))
# Out:
# 2520

# %%
x_train = np.array(images_train)
y_train = np.array(value_train)

x_valid = np.array(images_valid)
y_valid = np.array(value_valid)

x_test = np.array(images_test)
y_test = np.array(value_test)

# %%
a = 30000
plt.imshow(x_train[a],cmap = 'gray')
print(y_train[a])
# Out:
# 0

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.BatchNormalization())

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 62, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 63, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 14, 32)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 30, 14, 32)       128
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 28, 12, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 6, 64)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 4, 64)         36928
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 2, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 6, 2, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense (Dense)               (None, 64)                49216
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 114,657
# Trainable params: 114,465
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy','mse'])

#Funcka umożliwia zatrzymanie się uczenia
#gdy wartość strat przstanie maleć
EarlyStop = EarlyStopping(monitor='val_loss',
                          verbose=1,
                          patience=10)


ModelCheck = ModelCheckpoint(filepath='./Model_przeplatane_wiersze_2.h5',
                             monitor='val_loss',
                             save_best_only=True)

history = model.fit(x=x_train,
                    y=y_train,
                    epochs=100,
                    batch_size=128,
                    #validation_split=0.1,
                    validation_data = (x_valid, y_valid),
                    callbacks = [EarlyStop, ModelCheck]
                   )
# Out:
# Epoch 1/100
# 237/237 [==============================] - 52s 212ms/step - loss: 0.0065 - accuracy: 0.9960 - mse: 0.0065 - val_loss: 0.1045 - val_accuracy: 0.8464 - val_mse: 0.1045
# Epoch 2/100
# 237/237 [==============================] - 54s 228ms/step - loss: 0.0036 - accuracy: 0.9979 - mse: 0.0036 - val_loss: 0.1277 - val_accuracy: 0.8456 - val_mse: 0.1277
# Epoch 3/100
# 237/237 [==============================] - 55s 232ms/step - loss: 0.0014 - accuracy: 0.9998 - mse: 0.0014 - val_loss: 0.1329 - val_accuracy: 0.8286 - val_mse: 0.1329
# Epoch 4/100
# 237/237 [==============================] - 55s 232ms/step - loss: 0.0016 - accuracy: 0.9994 - mse: 0.0016 - val_loss: 0.0993 - val_accuracy: 0.8683 - val_mse: 0.0993
# Epoch 5/100
# 237/237 [==============================] - 55s 232ms/step - loss: 0.0014 - accuracy: 0.9997 - mse: 0.0014 - val_loss: 0.1057 - val_accuracy: 0.8536 - val_mse: 0.1057
# Epoch 6/100
# 237/237 [==============================] - 55s 232ms/step - loss: 0.0073 - accuracy: 0.9933 - mse: 0.0073 - val_loss: 0.2742 - val_accuracy: 0.7016 - val_mse: 0.2742
# Epoch 7/100
# 237/237 [==============================] - 56s 236ms/step - loss: 0.0017 - accuracy: 0.9992 - mse: 0.0017 - val_loss: 0.1648 - val_accuracy: 0.8052 - val_mse: 0.1648
# Epoch 8/100
# 237/237 [==============================] - 55s 233ms/step - loss: 8.6788e-04 - accuracy: 0.9996 - mse: 8.6788e-04 - val_loss: 0.1066 - val_accuracy: 0.8508 - val_mse: 0.1066
# Epoch 9/100
# 237/237 [==============================] - 55s 234ms/step - loss: 5.6664e-04 - accuracy: 0.9999 - mse: 5.6664e-04 - val_loss: 0.0905 - val_accuracy: 0.8877 - val_mse: 0.0905
# Epoch 10/100
# 237/237 [==============================] - 57s 239ms/step - loss: 5.2739e-04 - accuracy: 0.9999 - mse: 5.2739e-04 - val_loss: 0.1774 - val_accuracy: 0.7869 - val_mse: 0.1774
# Epoch 11/100
# 237/237 [==============================] - 55s 233ms/step - loss: 0.0014 - accuracy: 0.9993 - mse: 0.0014 - val_loss: 0.1291 - val_accuracy: 0.8417 - val_mse: 0.1291
# Epoch 12/100
# 237/237 [==============================] - 56s 238ms/step - loss: 5.9236e-04 - accuracy: 0.9998 - mse: 5.9236e-04 - val_loss: 0.1871 - val_accuracy: 0.7925 - val_mse: 0.1871
# Epoch 13/100
# 237/237 [==============================] - 56s 234ms/step - loss: 0.0014 - accuracy: 0.9991 - mse: 0.0014 - val_loss: 0.4564 - val_accuracy: 0.5321 - val_mse: 0.4564
# Epoch 14/100
# 237/237 [==============================] - 56s 237ms/step - loss: 0.0022 - accuracy: 0.9986 - mse: 0.0022 - val_loss: 0.1575 - val_accuracy: 0.8032 - val_mse: 0.1575
# Epoch 15/100
# 237/237 [==============================] - 55s 232ms/step - loss: 5.9090e-04 - accuracy: 0.9998 - mse: 5.9090e-04 - val_loss: 0.2398 - val_accuracy: 0.7313 - val_mse: 0.2398
# Epoch 16/100
# 237/237 [==============================] - 56s 235ms/step - loss: 3.6190e-04 - accuracy: 0.9999 - mse: 3.6190e-04 - val_loss: 0.0832 - val_accuracy: 0.8913 - val_mse: 0.0832
# Epoch 17/100
# 237/237 [==============================] - 56s 236ms/step - loss: 0.0013 - accuracy: 0.9991 - mse: 0.0013 - val_loss: 0.2341 - val_accuracy: 0.7448 - val_mse: 0.2341
# Epoch 18/100
# 237/237 [==============================] - 54s 229ms/step - loss: 4.4103e-04 - accuracy: 0.9998 - mse: 4.4103e-04 - val_loss: 0.1018 - val_accuracy: 0.8667 - val_mse: 0.1018
# Epoch 19/100
# 237/237 [==============================] - 56s 236ms/step - loss: 6.6938e-04 - accuracy: 0.9997 - mse: 6.6938e-04 - val_loss: 0.1041 - val_accuracy: 0.8722 - val_mse: 0.1041
# Epoch 20/100
# 237/237 [==============================] - 55s 231ms/step - loss: 0.0020 - accuracy: 0.9983 - mse: 0.0020 - val_loss: 0.2059 - val_accuracy: 0.7536 - val_mse: 0.2059
# Epoch 21/100
# 237/237 [==============================] - 55s 234ms/step - loss: 7.8402e-04 - accuracy: 0.9994 - mse: 7.8402e-04 - val_loss: 0.0738 - val_accuracy: 0.9048 - val_mse: 0.0738
# Epoch 22/100
# 237/237 [==============================] - 56s 236ms/step - loss: 2.3257e-04 - accuracy: 0.9999 - mse: 2.3257e-04 - val_loss: 0.0837 - val_accuracy: 0.8917 - val_mse: 0.0837
# Epoch 23/100
# 237/237 [==============================] - 55s 232ms/step - loss: 8.4499e-04 - accuracy: 0.9994 - mse: 8.4499e-04 - val_loss: 0.2552 - val_accuracy: 0.7226 - val_mse: 0.2552
# Epoch 24/100
# 237/237 [==============================] - 56s 237ms/step - loss: 0.0014 - accuracy: 0.9987 - mse: 0.0014 - val_loss: 0.2373 - val_accuracy: 0.7313 - val_mse: 0.2373
# Epoch 25/100
# 237/237 [==============================] - 56s 235ms/step - loss: 5.3479e-04 - accuracy: 0.9997 - mse: 5.3479e-04 - val_loss: 0.1053 - val_accuracy: 0.8718 - val_mse: 0.1053
# Epoch 26/100
# 237/237 [==============================] - 56s 235ms/step - loss: 4.0726e-04 - accuracy: 0.9997 - mse: 4.0726e-04 - val_loss: 0.0917 - val_accuracy: 0.8817 - val_mse: 0.0917
# Epoch 27/100
# 237/237 [==============================] - 56s 235ms/step - loss: 7.7171e-04 - accuracy: 0.9993 - mse: 7.7171e-04 - val_loss: 0.0959 - val_accuracy: 0.8813 - val_mse: 0.0959
# Epoch 28/100
# 237/237 [==============================] - 56s 235ms/step - loss: 3.5842e-04 - accuracy: 0.9997 - mse: 3.5842e-04 - val_loss: 0.0916 - val_accuracy: 0.8849 - val_mse: 0.0916
# Epoch 29/100
# 237/237 [==============================] - 56s 236ms/step - loss: 0.0017 - accuracy: 0.9984 - mse: 0.0017 - val_loss: 0.0786 - val_accuracy: 0.9060 - val_mse: 0.0786
# Epoch 30/100
# 237/237 [==============================] - 55s 234ms/step - loss: 2.7383e-04 - accuracy: 0.9998 - mse: 2.7383e-04 - val_loss: 0.1606 - val_accuracy: 0.8147 - val_mse: 0.1606
# Epoch 31/100
# 237/237 [==============================] - 56s 235ms/step - loss: 1.2321e-04 - accuracy: 1.0000 - mse: 1.2321e-04 - val_loss: 0.1138 - val_accuracy: 0.8587 - val_mse: 0.1138
# Epoch 31: early stopping

# %%
plt.plot(history.history['loss'], label='strata')
plt.plot(history.history['val_loss'], label = 'strata walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Strata')
plt.ylim([0.0, 0.5])
plt.legend(loc='upper right')

# %%
plt.plot(history.history['accuracy'], label='precyzja')
plt.plot(history.history['val_accuracy'], label = 'precyzja walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Precyzja')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
best_model = tf.keras.models.load_model('./Model_przeplatane_wiersze_2.h5')

# %%
best_model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 79/79 - 2s - loss: 0.1564 - accuracy: 0.8083 - mse: 0.1564 - 2s/epoch - 23ms/step
# [0.15640623137972398, 0.8083333333333333, 0.15640623137972398]

# %%
predict_x = best_model.predict(x_test)

predictions = (predict_x > 0.5).astype("int32")
# Out:
# 79/79 [==============================] - 2s 20ms/step

# %%
names = [['Tn','Nn'],['Np', 'Tp']]
names = np.reshape(names,(2,2))
print(names)

conf = tf.math.confusion_matrix(y_test,predictions)

print(conf)
# Out:
# [['Tn' 'Nn']
#  ['Np' 'Tp']]
# tf.Tensor(
# [[ 965  295]
#  [ 188 1072]], shape=(2, 2), dtype=int32)
