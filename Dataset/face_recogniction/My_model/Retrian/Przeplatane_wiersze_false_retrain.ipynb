# %%
import sys
print(sys.version)
# Out:
# 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers, models, regularizers
from keras.layers import Flatten, add, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping


print("TensorFlow version:", tf.__version__)
tf.keras.backend.set_floatx('float64')
# Out:
# TensorFlow version: 2.10.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os
import csv
import random

import cv2
import glob
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
# Dane fikcyjne
#Wczytanie etykiet do treninegu 

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\My_model_no_labels\Train\train.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))

value_train = []

for i in new[0]:
    value_train.append(int(i))

print(len(value_train))
# Out:
# 15120

# %%
#Wczytanie etykiet do walidacji

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Valid\valid.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_valid = []
for i in new[0]:
    value_valid.append(int(i))

print(len(value_valid))
# Out:
# 5040

# %%
#Wczytanie etykiet do testowania

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Test\test.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_test = []
for i in new[0]:
    value_test.append(int(i))

print(len(value_test))
# Out:
# 5040

# %%
#Dane fikcyjne
#Wczytanie zdjęć treningowych (75% całego zbioru)
#size = int(len(value_train)/2)

images_train = []

size = len(value_train)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\My_model_no_labels\Train\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_train.append(arr_im)
print(len(images_train))
# Out:
# 15120

# %%
#Wczytanie zdjęć walidacji (12,5% całego zbioru)
images_valid = []
size = len(value_valid)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Valid\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_valid.append(arr_im)
print(len(images_valid))
# Out:
# 5040

# %%
#Wczytanie zdjęć testowych (12,5% całego zbioru)
images_test = []
size = len(value_test)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Test\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_test.append(arr_im)
print(len(images_test))
# Out:
# 5040

# %%
x_train = np.array(images_train)
y_train = np.array(value_train)

x_valid = np.array(images_valid)
y_valid = np.array(value_valid)

x_test = np.array(images_test)
y_test = np.array(value_test)

# %%
a = 10000
plt.imshow(x_train[a],cmap = 'gray')
print(y_train[a])
# Out:
# 0

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.BatchNormalization())

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 62, 32)       320
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 31, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 29, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 14, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 30, 14, 32)       128
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 28, 12, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 6, 64)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 4, 64)         36928
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 2, 64)         0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 6, 2, 64)         256
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 768)               0
#
#  dense_2 (Dense)             (None, 64)                49216
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 114,657
# Trainable params: 114,465
# Non-trainable params: 192
# _________________________________________________________________

# %%
model = tf.keras.models.load_model(r"C:\Users\jankowiaka\Documents\python\mag\face_recogniction\Real\Model_przeplatane_wiersze_2.h5")

# %%
#Funcka umożliwia zatrzymanie się uczenia
#gdy wartość strat przstanie maleć
EarlyStop = EarlyStopping(monitor='val_loss',
                          verbose=1,
                          patience=10)


ModelCheck = ModelCheckpoint(filepath='./Model_przeplatane_wiersze_retrain_1.h5',
                             monitor='val_loss',
                             save_best_only=True)

history = model.fit(x=x_train,
                    y=y_train,
                    epochs=100,
                    batch_size=128,
                    #validation_split=0.1,
                    validation_data = (x_valid, y_valid),
                    callbacks = [EarlyStop, ModelCheck]
                   )
# Out:
# Epoch 1/100
# 119/119 [==============================] - 28s 220ms/step - loss: 0.0419 - accuracy: 0.9524 - mse: 0.0419 - val_loss: 0.1920 - val_accuracy: 0.7431 - val_mse: 0.1920
# Epoch 2/100
# 119/119 [==============================] - 25s 214ms/step - loss: 0.0116 - accuracy: 0.9868 - mse: 0.0116 - val_loss: 0.1851 - val_accuracy: 0.7512 - val_mse: 0.1851
# Epoch 3/100
# 119/119 [==============================] - 26s 219ms/step - loss: 0.0058 - accuracy: 0.9948 - mse: 0.0058 - val_loss: 0.2167 - val_accuracy: 0.7440 - val_mse: 0.2167
# Epoch 4/100
# 119/119 [==============================] - 29s 246ms/step - loss: 0.0037 - accuracy: 0.9965 - mse: 0.0037 - val_loss: 0.0764 - val_accuracy: 0.8980 - val_mse: 0.0764
# Epoch 5/100
# 119/119 [==============================] - 29s 241ms/step - loss: 0.0031 - accuracy: 0.9972 - mse: 0.0031 - val_loss: 0.1097 - val_accuracy: 0.8593 - val_mse: 0.1097
# Epoch 6/100
# 119/119 [==============================] - 61s 512ms/step - loss: 0.0018 - accuracy: 0.9986 - mse: 0.0018 - val_loss: 0.0783 - val_accuracy: 0.8996 - val_mse: 0.0783
# Epoch 7/100
# 119/119 [==============================] - 39s 323ms/step - loss: 0.0015 - accuracy: 0.9987 - mse: 0.0015 - val_loss: 0.1712 - val_accuracy: 0.7944 - val_mse: 0.1712
# Epoch 8/100
# 119/119 [==============================] - 26s 217ms/step - loss: 8.5586e-04 - accuracy: 0.9993 - mse: 8.5586e-04 - val_loss: 0.0650 - val_accuracy: 0.9171 - val_mse: 0.0650
# Epoch 9/100
# 119/119 [==============================] - 27s 226ms/step - loss: 8.3215e-04 - accuracy: 0.9993 - mse: 8.3215e-04 - val_loss: 0.3027 - val_accuracy: 0.6794 - val_mse: 0.3027
# Epoch 10/100
# 119/119 [==============================] - 29s 246ms/step - loss: 0.0011 - accuracy: 0.9991 - mse: 0.0011 - val_loss: 0.0771 - val_accuracy: 0.9058 - val_mse: 0.0771
# Epoch 11/100
# 119/119 [==============================] - 30s 255ms/step - loss: 5.4018e-04 - accuracy: 0.9997 - mse: 5.4018e-04 - val_loss: 0.1164 - val_accuracy: 0.8599 - val_mse: 0.1164
# Epoch 12/100
# 119/119 [==============================] - 30s 249ms/step - loss: 4.1453e-04 - accuracy: 0.9997 - mse: 4.1453e-04 - val_loss: 0.1082 - val_accuracy: 0.8645 - val_mse: 0.1082
# Epoch 13/100
# 119/119 [==============================] - 30s 254ms/step - loss: 6.0839e-04 - accuracy: 0.9995 - mse: 6.0839e-04 - val_loss: 0.0783 - val_accuracy: 0.9050 - val_mse: 0.0783
# Epoch 14/100
# 119/119 [==============================] - 31s 259ms/step - loss: 5.0197e-04 - accuracy: 0.9997 - mse: 5.0197e-04 - val_loss: 0.0673 - val_accuracy: 0.9127 - val_mse: 0.0673
# Epoch 15/100
# 119/119 [==============================] - 30s 256ms/step - loss: 4.6662e-04 - accuracy: 0.9996 - mse: 4.6662e-04 - val_loss: 0.1508 - val_accuracy: 0.8260 - val_mse: 0.1508
# Epoch 16/100
# 119/119 [==============================] - 30s 253ms/step - loss: 8.3648e-04 - accuracy: 0.9992 - mse: 8.3648e-04 - val_loss: 0.0848 - val_accuracy: 0.8937 - val_mse: 0.0848
# Epoch 17/100
# 119/119 [==============================] - 30s 251ms/step - loss: 0.0037 - accuracy: 0.9964 - mse: 0.0037 - val_loss: 0.3538 - val_accuracy: 0.6194 - val_mse: 0.3538
# Epoch 18/100
# 119/119 [==============================] - 31s 263ms/step - loss: 0.0012 - accuracy: 0.9988 - mse: 0.0012 - val_loss: 0.0985 - val_accuracy: 0.8788 - val_mse: 0.0985
# Epoch 18: early stopping

# %%
plt.plot(history.history['loss'], label='strata')
plt.plot(history.history['val_loss'], label = 'strata walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Strata')
plt.ylim([0.0, 0.5])
plt.legend(loc='upper right')

# %%
plt.plot(history.history['accuracy'], label='precyzja')
plt.plot(history.history['val_accuracy'], label = 'precyzja walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Precyzja')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
best_model = tf.keras.models.load_model('./Model_przeplatane_wiersze_retrain_szum_1.h5')

# %%
best_model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 158/158 - 4s - loss: 0.1413 - accuracy: 0.8163 - mse: 0.1413 - 4s/epoch - 23ms/step
# [0.14130697823433272, 0.8162698412698413, 0.14130697823433272]

# %%
predict_x = best_model.predict(x_test)

predictions = (predict_x > 0.5).astype("int32")
# Out:
# 158/158 [==============================] - 3s 20ms/step

# %%
names = [['Tn','Nn'],['Np', 'Tp']]
names = np.reshape(names,(2,2))
print(names)

conf = tf.math.confusion_matrix(y_test,predictions)

print(conf)
# Out:
# [['Tn' 'Nn']
#  ['Np' 'Tp']]
# tf.Tensor(
# [[2104  416]
#  [ 510 2010]], shape=(2, 2), dtype=int32)
