# %%
import sys
print(sys.version)
# Out:
# 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers, models, regularizers
from keras.layers import Flatten, add, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping


print("TensorFlow version:", tf.__version__)
tf.keras.backend.set_floatx('float64')
# Out:
# TensorFlow version: 2.10.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import os
import csv
import random

import cv2
import glob
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
# Dane rzeczywiste
#Wczytanie etykiet do treninegu 

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Train\train.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_train = []
for i in new[0]:
    value_train.append(int(i))

print(len(value_train))
# Out:
# 15120

# %%
# Dane fikcyjne
#Wczytanie etykiet do treninegu 

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\My_model_no_labels\Train\train.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))

for i in new[0]:
    value_train.append(int(i))

print(len(value_train))
# Out:
# 30240

# %%
#Wczytanie etykiet do walidacji

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Valid\valid.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_valid = []
for i in new[0]:
    value_valid.append(int(i))

print(len(value_valid))
# Out:
# 2520

# %%
#Wczytanie etykiet do testowania

with open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Test\test.csv","r") as csvfile:
    lines = csvfile.readlines()
csvfile.close()

new = []

for i in lines:
    new.append(i.split(" "))


value_test = []
for i in new[0]:
    value_test.append(int(i))

print(len(value_test))
# Out:
# 2520

# %%
#Dane rzeczywiste
#Wczytanie zdjęć treningowych (75% całego zbioru)
images_train = []
#size = int(len(value_train)/2)
size = 15120

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Train\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_train.append(arr_im)
print(len(images_train))
# Out:
# 15120

# %%
#Dane fikcyjne
#Wczytanie zdjęć treningowych (75% całego zbioru)
#size = int(len(value_train)/2)
size = 15120

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\My_model_no_labels\Train\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_train.append(arr_im)
print(len(images_train))
# Out:
# 30240

# %%
#Wczytanie zdjęć walidacji (12,5% całego zbioru)
images_valid = []
size = len(value_valid)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Valid\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_valid.append(arr_im)
print(len(images_valid))
# Out:
# 2520

# %%
#Wczytanie zdjęć testowych (12,5% całego zbioru)
images_test = []
size = len(value_test)

for i in range(size):
    im = Image.open(r"C:\Users\jankowiaka\Documents\python\mag\Dataset_both\Real\Test\\"+str(i)+'.png')
    arr_im = np.array(im)
    arr_im = arr_im / 255.0
    images_test.append(arr_im)
print(len(images_test))
# Out:
# 2520

# %%
x_train = np.array(images_train)
y_train = np.array(value_train)

x_valid = np.array(images_valid)
y_valid = np.array(value_valid)

x_test = np.array(images_test)
y_test = np.array(value_test)

# %%
a = 30000
plt.imshow(x_train[a],cmap = 'gray')
print(y_train[a])
# Out:
# 0

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 64, 1)))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.BatchNormalization())

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 62, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 63, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 14, 32)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 30, 14, 32)       128
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 28, 12, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 6, 64)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 4, 64)         36928
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 2, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 6, 2, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense (Dense)               (None, 64)                49216
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 114,657
# Trainable params: 114,465
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy','mse'])

#Funcka umożliwia zatrzymanie się uczenia
#gdy wartość strat przstanie maleć
EarlyStop = EarlyStopping(monitor='val_loss',
                          verbose=1,
                          patience=20)


ModelCheck = ModelCheckpoint(filepath='./Model_przeplatane_wiersze_2.h5',
                             monitor='val_loss',
                             save_best_only=True)

history = model.fit(x=x_train,
                    y=y_train,
                    epochs=100,
                    batch_size=128,
                    #validation_split=0.1,
                    validation_data = (x_valid, y_valid),
                    callbacks = [EarlyStop, ModelCheck]
                   )
# Out:
# Epoch 1/100
# 237/237 [==============================] - 49s 202ms/step - loss: 0.0011 - accuracy: 0.9992 - mse: 0.0011 - val_loss: 0.0996 - val_accuracy: 0.8833 - val_mse: 0.0996
# Epoch 2/100
# 237/237 [==============================] - 47s 198ms/step - loss: 5.5433e-04 - accuracy: 0.9997 - mse: 5.5433e-04 - val_loss: 0.1192 - val_accuracy: 0.8425 - val_mse: 0.1192
# Epoch 3/100
# 237/237 [==============================] - 49s 207ms/step - loss: 6.2532e-04 - accuracy: 0.9995 - mse: 6.2532e-04 - val_loss: 0.1007 - val_accuracy: 0.8758 - val_mse: 0.1007
# Epoch 4/100
# 237/237 [==============================] - 54s 227ms/step - loss: 8.3295e-04 - accuracy: 0.9994 - mse: 8.3295e-04 - val_loss: 0.0875 - val_accuracy: 0.8937 - val_mse: 0.0875
# Epoch 5/100
# 237/237 [==============================] - 54s 229ms/step - loss: 9.6651e-04 - accuracy: 0.9992 - mse: 9.6651e-04 - val_loss: 0.0974 - val_accuracy: 0.8861 - val_mse: 0.0974
# Epoch 6/100
# 237/237 [==============================] - 56s 236ms/step - loss: 4.9712e-04 - accuracy: 0.9996 - mse: 4.9712e-04 - val_loss: 0.0981 - val_accuracy: 0.8790 - val_mse: 0.0981
# Epoch 7/100
# 237/237 [==============================] - 56s 238ms/step - loss: 1.0706e-04 - accuracy: 1.0000 - mse: 1.0706e-04 - val_loss: 0.0810 - val_accuracy: 0.8940 - val_mse: 0.0810
# Epoch 8/100
# 237/237 [==============================] - 57s 239ms/step - loss: 8.6532e-05 - accuracy: 1.0000 - mse: 8.6532e-05 - val_loss: 0.0798 - val_accuracy: 0.8980 - val_mse: 0.0798
# Epoch 9/100
# 237/237 [==============================] - 58s 243ms/step - loss: 1.0813e-04 - accuracy: 1.0000 - mse: 1.0813e-04 - val_loss: 0.0844 - val_accuracy: 0.8976 - val_mse: 0.0844
# Epoch 10/100
# 237/237 [==============================] - 57s 241ms/step - loss: 7.4340e-04 - accuracy: 0.9994 - mse: 7.4340e-04 - val_loss: 0.1027 - val_accuracy: 0.8762 - val_mse: 0.1027
# Epoch 11/100
# 237/237 [==============================] - 57s 240ms/step - loss: 0.0014 - accuracy: 0.9987 - mse: 0.0014 - val_loss: 0.1151 - val_accuracy: 0.8560 - val_mse: 0.1151
# Epoch 12/100
# 237/237 [==============================] - 58s 244ms/step - loss: 5.6019e-04 - accuracy: 0.9996 - mse: 5.6019e-04 - val_loss: 0.0638 - val_accuracy: 0.9135 - val_mse: 0.0638
# Epoch 13/100
# 237/237 [==============================] - 57s 241ms/step - loss: 2.7723e-04 - accuracy: 0.9998 - mse: 2.7723e-04 - val_loss: 0.1282 - val_accuracy: 0.8504 - val_mse: 0.1282
# Epoch 14/100
# 237/237 [==============================] - 57s 242ms/step - loss: 5.4982e-04 - accuracy: 0.9995 - mse: 5.4982e-04 - val_loss: 0.0787 - val_accuracy: 0.9000 - val_mse: 0.0787
# Epoch 15/100
# 237/237 [==============================] - 57s 241ms/step - loss: 2.4294e-04 - accuracy: 0.9998 - mse: 2.4294e-04 - val_loss: 0.1302 - val_accuracy: 0.8456 - val_mse: 0.1302
# Epoch 16/100
# 237/237 [==============================] - 57s 240ms/step - loss: 6.4249e-05 - accuracy: 1.0000 - mse: 6.4249e-05 - val_loss: 0.0784 - val_accuracy: 0.9087 - val_mse: 0.0784
# Epoch 17/100
# 237/237 [==============================] - 57s 240ms/step - loss: 2.4076e-04 - accuracy: 0.9999 - mse: 2.4076e-04 - val_loss: 0.1020 - val_accuracy: 0.8798 - val_mse: 0.1020
# Epoch 18/100
# 237/237 [==============================] - 58s 245ms/step - loss: 3.8718e-04 - accuracy: 0.9997 - mse: 3.8718e-04 - val_loss: 0.4203 - val_accuracy: 0.5726 - val_mse: 0.4203
# Epoch 19/100
# 237/237 [==============================] - 57s 239ms/step - loss: 0.0011 - accuracy: 0.9989 - mse: 0.0011 - val_loss: 0.1051 - val_accuracy: 0.8746 - val_mse: 0.1051
# Epoch 20/100
# 237/237 [==============================] - 57s 240ms/step - loss: 3.2011e-04 - accuracy: 0.9997 - mse: 3.2011e-04 - val_loss: 0.1226 - val_accuracy: 0.8595 - val_mse: 0.1226
# Epoch 21/100
# 237/237 [==============================] - 58s 244ms/step - loss: 1.0759e-04 - accuracy: 0.9999 - mse: 1.0759e-04 - val_loss: 0.0815 - val_accuracy: 0.8984 - val_mse: 0.0815
# Epoch 22/100
# 237/237 [==============================] - 59s 248ms/step - loss: 1.2924e-04 - accuracy: 0.9999 - mse: 1.2924e-04 - val_loss: 0.4294 - val_accuracy: 0.5575 - val_mse: 0.4294
# Epoch 23/100
# 237/237 [==============================] - 57s 241ms/step - loss: 7.3982e-04 - accuracy: 0.9993 - mse: 7.3982e-04 - val_loss: 0.1176 - val_accuracy: 0.8587 - val_mse: 0.1176
# Epoch 24/100
# 237/237 [==============================] - 58s 244ms/step - loss: 7.8131e-04 - accuracy: 0.9991 - mse: 7.8131e-04 - val_loss: 0.1871 - val_accuracy: 0.7869 - val_mse: 0.1871
# Epoch 25/100
# 237/237 [==============================] - 58s 244ms/step - loss: 0.0012 - accuracy: 0.9989 - mse: 0.0012 - val_loss: 0.0898 - val_accuracy: 0.8952 - val_mse: 0.0898
# Epoch 26/100
# 237/237 [==============================] - 58s 246ms/step - loss: 3.2138e-04 - accuracy: 0.9997 - mse: 3.2138e-04 - val_loss: 0.1344 - val_accuracy: 0.8472 - val_mse: 0.1344
# Epoch 27/100
# 237/237 [==============================] - 59s 250ms/step - loss: 2.8982e-04 - accuracy: 0.9998 - mse: 2.8982e-04 - val_loss: 0.0892 - val_accuracy: 0.8976 - val_mse: 0.0892
# Epoch 28/100
# 237/237 [==============================] - 84s 356ms/step - loss: 5.2861e-05 - accuracy: 1.0000 - mse: 5.2861e-05 - val_loss: 0.0909 - val_accuracy: 0.8964 - val_mse: 0.0909
# Epoch 29/100
# 237/237 [==============================] - 77s 325ms/step - loss: 2.5186e-04 - accuracy: 0.9997 - mse: 2.5186e-04 - val_loss: 0.1338 - val_accuracy: 0.8365 - val_mse: 0.1338
# Epoch 30/100
# 237/237 [==============================] - 78s 331ms/step - loss: 1.9525e-04 - accuracy: 0.9999 - mse: 1.9525e-04 - val_loss: 0.0928 - val_accuracy: 0.8913 - val_mse: 0.0928
# Epoch 31/100
# 237/237 [==============================] - 77s 324ms/step - loss: 5.9097e-05 - accuracy: 1.0000 - mse: 5.9097e-05 - val_loss: 0.0932 - val_accuracy: 0.8937 - val_mse: 0.0932
# Epoch 32/100
# 237/237 [==============================] - 78s 330ms/step - loss: 1.1167e-04 - accuracy: 0.9999 - mse: 1.1167e-04 - val_loss: 0.0795 - val_accuracy: 0.9071 - val_mse: 0.0795
# Epoch 32: early stopping

# %%
plt.plot(history.history['loss'], label='strata')
plt.plot(history.history['val_loss'], label = 'strata walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Strata')
plt.ylim([0.0, 0.5])
plt.legend(loc='upper right')

# %%
plt.plot(history.history['accuracy'], label='precyzja')
plt.plot(history.history['val_accuracy'], label = 'precyzja walidacyjna')
plt.xlabel('Epoka')
plt.ylabel('Precyzja')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
best_model = tf.keras.models.load_model('./Model_przeplatane_wiersze_2.h5')

# %%
best_model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 79/79 - 4s - loss: 0.1474 - accuracy: 0.8210 - mse: 0.1474 - 4s/epoch - 45ms/step
# [0.14739889200890632, 0.821031746031746, 0.14739889200890632]

# %%
predict_x = best_model.predict(x_test)

predictions = (predict_x > 0.5).astype("int32")
# Out:
# 79/79 [==============================] - 2s 20ms/step

# %%
names = [['Tn','Nn'],['Np', 'Tp']]
names = np.reshape(names,(2,2))
print(names)

conf = tf.math.confusion_matrix(y_test,predictions)

print(conf)
# Out:
# [['Tn' 'Nn']
#  ['Np' 'Tp']]
# tf.Tensor(
# [[1241   19]
#  [ 478  782]], shape=(2, 2), dtype=int32)
